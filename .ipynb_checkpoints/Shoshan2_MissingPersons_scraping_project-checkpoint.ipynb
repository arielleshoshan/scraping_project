# %%
# !pip install selenium
# !pip install webdriver
# !pip install webdrivermanager
# !pip install webdriver_manager
# Out:
# Requirement already satisfied: selenium in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (4.8.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from selenium) (1.26.14)
# Requirement already satisfied: trio~=0.17 in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from selenium) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from selenium) (0.10.0)
# Requirement already satisfied: certifi>=2021.10.8 in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from selenium) (2022.12.7)
# Requirement already satisfied: attrs>=19.2.0 in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from trio~=0.17->selenium) (22.2.0)
# Requirement already satisfied: sortedcontainers in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: idna in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: exceptiongroup in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from trio-websocket~=0.9->selenium) (1.1.1)
# Requirement already satisfied: wsproto>=0.14 in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# ERROR: Could not find a version that satisfies the requirement webdriver (from versions: none)
# ERROR: No matching distribution found for webdriver
# Collecting webdrivermanager
#   Using cached webdrivermanager-0.10.0-py2.py3-none-any.whl
# Requirement already satisfied: requests in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from webdrivermanager) (2.28.2)
# Requirement already satisfied: tqdm in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from webdrivermanager) (4.65.0)
# Requirement already satisfied: BeautifulSoup4 in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from webdrivermanager) (4.11.2)
# Requirement already satisfied: appdirs in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from webdrivermanager) (1.4.4)
# Collecting lxml
#   Using cached lxml-4.9.2.tar.gz (3.7 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: soupsieve>1.2 in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from BeautifulSoup4->webdrivermanager) (2.3.2.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from requests->webdrivermanager) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from requests->webdrivermanager) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from requests->webdrivermanager) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from requests->webdrivermanager) (2022.12.7)
# Installing collected packages: lxml, webdrivermanager
#   DEPRECATION: lxml is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for lxml ... error
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for lxml did not run successfully.
#   │ exit code: 1
#   ╰─> [121 lines of output]
#       Building lxml version 4.9.2.
#       Building without Cython.
#       Building against libxml2 2.9.13 and libxslt 1.1.35
#       running install
#       /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-10.9-universal2-cpython-311
#       creating build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/_elementpath.py -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/sax.py -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/pyclasslookup.py -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/builder.py -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/doctestcompare.py -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/usedoctest.py -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/cssselect.py -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/ElementInclude.py -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       creating build/lib.macosx-10.9-universal2-cpython-311/lxml/includes
#       copying src/lxml/includes/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/lxml/includes
#       creating build/lib.macosx-10.9-universal2-cpython-311/lxml/html
#       copying src/lxml/html/soupparser.py -> build/lib.macosx-10.9-universal2-cpython-311/lxml/html
#       copying src/lxml/html/defs.py -> build/lib.macosx-10.9-universal2-cpython-311/lxml/html
#       copying src/lxml/html/_setmixin.py -> build/lib.macosx-10.9-universal2-cpython-311/lxml/html
#       copying src/lxml/html/clean.py -> build/lib.macosx-10.9-universal2-cpython-311/lxml/html
#       copying src/lxml/html/_diffcommand.py -> build/lib.macosx-10.9-universal2-cpython-311/lxml/html
#       copying src/lxml/html/html5parser.py -> build/lib.macosx-10.9-universal2-cpython-311/lxml/html
#       copying src/lxml/html/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/lxml/html
#       copying src/lxml/html/formfill.py -> build/lib.macosx-10.9-universal2-cpython-311/lxml/html
#       copying src/lxml/html/builder.py -> build/lib.macosx-10.9-universal2-cpython-311/lxml/html
#       copying src/lxml/html/ElementSoup.py -> build/lib.macosx-10.9-universal2-cpython-311/lxml/html
#       copying src/lxml/html/_html5builder.py -> build/lib.macosx-10.9-universal2-cpython-311/lxml/html
#       copying src/lxml/html/usedoctest.py -> build/lib.macosx-10.9-universal2-cpython-311/lxml/html
#       copying src/lxml/html/diff.py -> build/lib.macosx-10.9-universal2-cpython-311/lxml/html
#       creating build/lib.macosx-10.9-universal2-cpython-311/lxml/isoschematron
#       copying src/lxml/isoschematron/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/lxml/isoschematron
#       copying src/lxml/etree.h -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/etree_api.h -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/lxml.etree.h -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/lxml.etree_api.h -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/objectify.pyx -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/etree.pyx -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/public-api.pxi -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/xmlid.pxi -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/cleanup.pxi -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/xslt.pxi -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/xpath.pxi -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/debug.pxi -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/serializer.pxi -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/classlookup.pxi -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/saxparser.pxi -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/objectpath.pxi -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/relaxng.pxi -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/xinclude.pxi -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/iterparse.pxi -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/parser.pxi -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/dtd.pxi -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/apihelpers.pxi -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/xmlerror.pxi -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/readonlytree.pxi -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/extensions.pxi -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/xmlschema.pxi -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/schematron.pxi -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/docloader.pxi -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/nsclasses.pxi -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/parsertarget.pxi -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/xsltext.pxi -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/proxy.pxi -> build/lib.macosx-10.9-universal2-cpython-311/lxml
#       copying src/lxml/includes/xmlerror.pxd -> build/lib.macosx-10.9-universal2-cpython-311/lxml/includes
#       copying src/lxml/includes/c14n.pxd -> build/lib.macosx-10.9-universal2-cpython-311/lxml/includes
#       copying src/lxml/includes/xmlschema.pxd -> build/lib.macosx-10.9-universal2-cpython-311/lxml/includes
#       copying src/lxml/includes/__init__.pxd -> build/lib.macosx-10.9-universal2-cpython-311/lxml/includes
#       copying src/lxml/includes/schematron.pxd -> build/lib.macosx-10.9-universal2-cpython-311/lxml/includes
#       copying src/lxml/includes/tree.pxd -> build/lib.macosx-10.9-universal2-cpython-311/lxml/includes
#       copying src/lxml/includes/uri.pxd -> build/lib.macosx-10.9-universal2-cpython-311/lxml/includes
#       copying src/lxml/includes/etreepublic.pxd -> build/lib.macosx-10.9-universal2-cpython-311/lxml/includes
#       copying src/lxml/includes/xpath.pxd -> build/lib.macosx-10.9-universal2-cpython-311/lxml/includes
#       copying src/lxml/includes/htmlparser.pxd -> build/lib.macosx-10.9-universal2-cpython-311/lxml/includes
#       copying src/lxml/includes/xslt.pxd -> build/lib.macosx-10.9-universal2-cpython-311/lxml/includes
#       copying src/lxml/includes/config.pxd -> build/lib.macosx-10.9-universal2-cpython-311/lxml/includes
#       copying src/lxml/includes/xmlparser.pxd -> build/lib.macosx-10.9-universal2-cpython-311/lxml/includes
#       copying src/lxml/includes/xinclude.pxd -> build/lib.macosx-10.9-universal2-cpython-311/lxml/includes
#       copying src/lxml/includes/dtdvalid.pxd -> build/lib.macosx-10.9-universal2-cpython-311/lxml/includes
#       copying src/lxml/includes/relaxng.pxd -> build/lib.macosx-10.9-universal2-cpython-311/lxml/includes
#       copying src/lxml/includes/lxml-version.h -> build/lib.macosx-10.9-universal2-cpython-311/lxml/includes
#       copying src/lxml/includes/etree_defs.h -> build/lib.macosx-10.9-universal2-cpython-311/lxml/includes
#       creating build/lib.macosx-10.9-universal2-cpython-311/lxml/isoschematron/resources
#       creating build/lib.macosx-10.9-universal2-cpython-311/lxml/isoschematron/resources/rng
#       copying src/lxml/isoschematron/resources/rng/iso-schematron.rng -> build/lib.macosx-10.9-universal2-cpython-311/lxml/isoschematron/resources/rng
#       creating build/lib.macosx-10.9-universal2-cpython-311/lxml/isoschematron/resources/xsl
#       copying src/lxml/isoschematron/resources/xsl/XSD2Schtrn.xsl -> build/lib.macosx-10.9-universal2-cpython-311/lxml/isoschematron/resources/xsl
#       copying src/lxml/isoschematron/resources/xsl/RNG2Schtrn.xsl -> build/lib.macosx-10.9-universal2-cpython-311/lxml/isoschematron/resources/xsl
#       creating build/lib.macosx-10.9-universal2-cpython-311/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_abstract_expand.xsl -> build/lib.macosx-10.9-universal2-cpython-311/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_dsdl_include.xsl -> build/lib.macosx-10.9-universal2-cpython-311/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_schematron_skeleton_for_xslt1.xsl -> build/lib.macosx-10.9-universal2-cpython-311/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_svrl_for_xslt1.xsl -> build/lib.macosx-10.9-universal2-cpython-311/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_schematron_message.xsl -> build/lib.macosx-10.9-universal2-cpython-311/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/readme.txt -> build/lib.macosx-10.9-universal2-cpython-311/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       running build_ext
#       building 'lxml.etree' extension
#       creating build/temp.macosx-10.9-universal2-cpython-311
#       creating build/temp.macosx-10.9-universal2-cpython-311/src
#       creating build/temp.macosx-10.9-universal2-cpython-311/src/lxml
#       clang -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -arch arm64 -arch x86_64 -g -DCYTHON_CLINE_IN_TRACEBACK=0 -I/usr/include -Isrc -Isrc/lxml/includes -I/Users/rel/Documents/python/jupyter_work/env/include -I/Library/Frameworks/Python.framework/Versions/3.11/include/python3.11 -c src/lxml/etree.c -o build/temp.macosx-10.9-universal2-cpython-311/src/lxml/etree.o -w -flat_namespace
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       Compile failed: command '/usr/bin/clang' failed with exit code 1
#       creating var
#       creating var/folders
#       creating var/folders/9_
#       creating var/folders/9_/7d5m3sk556zgz5wt5cbkct3r0000gn
#       creating var/folders/9_/7d5m3sk556zgz5wt5cbkct3r0000gn/T
#       cc -I/usr/include -I/usr/include/libxml2 -c /var/folders/9_/7d5m3sk556zgz5wt5cbkct3r0000gn/T/xmlXPathInitcyhlbfij.c -o var/folders/9_/7d5m3sk556zgz5wt5cbkct3r0000gn/T/xmlXPathInitcyhlbfij.o
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       *********************************************************************************
#       Could not find function xmlCheckVersion in library libxml2. Is libxml2 installed?
#       Perhaps try: xcode-select --install
#       *********************************************************************************
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> lxml
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.
# Requirement already satisfied: webdriver_manager in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (3.8.5)
# Requirement already satisfied: requests in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from webdriver_manager) (2.28.2)
# Requirement already satisfied: python-dotenv in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from webdriver_manager) (1.0.0)
# Requirement already satisfied: tqdm in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from webdriver_manager) (4.65.0)
# Requirement already satisfied: packaging in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from webdriver_manager) (23.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from requests->webdriver_manager) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from requests->webdriver_manager) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from requests->webdriver_manager) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rel/Documents/python/jupyter_work/env/lib/python3.11/site-packages (from requests->webdriver_manager) (2022.12.7)

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdrivermanager.chrome import ChromeDriverManager
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 3
#       1 from selenium import webdriver
#       2 from selenium.webdriver.chrome.service import Service
# ----> 3 from webdrivermanager.chrome import ChromeDriverManager
#
# ModuleNotFoundError: No module named 'webdrivermanager'

# %%
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import requests
import time
import csv

# %%
# arielle
start_page = "https://www.fdle.state.fl.us/MCICSearch/Search.asp"

driver = webdriver.Chrome()
driver.get(start_page)

# use Select () to get the select drop-down menu
category_menu = Select(driver.find_element(By.ID, "category"))

# go to 5th option in the select element
category_menu.select_by_index(4)


#now press search button, select by XPATH
search_button = driver.find_element(By.XPATH, "//*[@id='SecondaryPageRightColumnInnerContent']/div[1]/div[19]/img")
search_button.click()

#list to save all the missing person's data
data_list = []

#this function extracts the missing person data from the table using beautifulsoup
def extract_data(driver, data_list):
    # extract the HTML source code
    html = driver.page_source

    # parse the HTML using Beautiful Soup
    soup = BeautifulSoup(html, "html.parser")

    # find the table element by its id or xpath
    table = soup.find("table", class_="DataTable")
    # loop through the rows and extract the data
    for row in table.find_all("tr"):
        cells = row.find_all("td")
        #list to save each missing person data as a list into the main data_list
        missing_person = []
        for index, cell in enumerate(cells):
            # extract data only from the 2nd, 3rd, and last cells from the missing data table
            if index == 1 or index == 2 or index == len(cells) - 1:
                # get the text of the cell
                data = cell.text
                #strip the data and append into the list
                missing_person.append(data.strip())
        data_list.append(missing_person)


# this function uses a for loop to jump to the next page and extract data for the particular page
def next_page(driver):
    for i in range(3, 31):
        # using Select () to get the select drop-down menu for next page
        next_page = Select(driver.find_element(By.ID, "PageListTop"))
        next_page.select_by_index(i)
        
        #extract data will append the current page data to data_list
        extract_data(driver, data_list)
        time.sleep(1)
        
    #these 3 lines gets the last page's missing persons data
    next_page = driver.find_element(By.XPATH, "//*[@id='SecondaryPageRightColumnInnerContent']/div[2]/strong[5]/a")
    next_page.click()
    extract_data(driver, data_list)
        

def create_missing_person_csv(data):
    # Remove the first 3 elements from the data list
    columns = ['Missing Since', 'Name', 'Missing From']
    data = data[1:]
#     print(data)

    # Open a new file for writing
    with open('missing_person_data.csv', mode='w', newline='') as file:
        # Create a CSV writer object
        writer = csv.writer(file)

        # Write the header row
        writer.writerow(["Name", "Missing Since", "Missing From"])

        # Loop through the data list and write each row to the CSV file
        for missing_person in data:
            if len(missing_person) == 3:
                print(missing_person)
                if missing_person != columns:
#                     print(missing_person)
                    name = missing_person[1]
#                     print("Name: ", name)
                    missing_since = missing_person[0]
#                     print("Missing Since: ", missing_since)
                    missing_from = missing_person[2]
#                     print("Missing From: ", missing_from)

                    writer.writerow([name, missing_since, missing_from])
            else:
                print("Data incomplete")

    print("CSV file created successfully!")

next_page(driver)
create_missing_person_csv(data_list)
